# %% [markdown]
# # An Analysis of all restaurants on the Michelin Guide
#
# For those who know me, you would know that I like to be wined and dined. I am not particularly a Michelin star catcher but I do not mind an occassional Michelin star meal on special occassions. These Michelin star restaurants are dotted all over the world. I was intrigued to know where these Michelin restaurants are located in the world so I can plan my next trip strategically and visit as many of them as possible in one location.
#
# This analysis aims to find:
# - Number of Michelin restaurants awared in 2025;
# - The city and country with the most Michelin restaurants;
# - What cuisines are awarded them most Michelin recognition.

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Load datase to df
df = pd.read_csv('michelin_my_maps.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17746 entries, 0 to 17745
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   17746 non-null  object
#  1   Address                17746 non-null  object
#  2   Location               17746 non-null  object
#  3   Price                  17745 non-null  object
#  4   Cuisine                17746 non-null  object
#  5   Longitude              17746 non-null  float64
#  6   Latitude               17746 non-null  float64
#  7   PhoneNumber            17377 non-null  float64
#  8   Url                    17746 non-null  object
#  9   WebsiteUrl             15242 non-null  object
#  10  Award                  17746 non-null  object
#  11  GreenStar              17746 non-null  int64
#  12  FacilitiesAndServices  16827 non-null  object
#  13  Description            17746 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB

# %%
#number of awards given to restaurants

award = df.groupby('Award').size().sort_values(ascending=False).reset_index(name = 'Count')

award

sns.barplot(data= award, x = 'Award', y = 'Count', hue = 'Award', palette = 'rocket_r')
plt.xlabel('Award')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Number of Michelin Restaurants Worldwide in 2025 by Award Level')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %%
#City with the most Michelin Restaurants

top_city = df.pivot_table(index = ['Award'], columns= ['Location'], aggfunc= 'size')
top_city.loc['Total'] = top_city.sum()
top_city = top_city[top_city.loc['Total'].sort_values(ascending=False).index]
top_city = top_city.drop('Total')
top_city
# Out:
# Location              Tokyo, Japan  Paris, France  London, United Kingdom  \
# Award
# 1 Star                       132.0           94.0                    63.0
# 2 Stars                       25.0           15.0                    14.0
# 3 Stars                       12.0           10.0                     6.0
# Bib Gourmand                 110.0           30.0                    42.0
# Selected Restaurants         232.0          316.0                   209.0
#
# Location              Singapore  Kyoto, Japan  New York, USA  Osaka, Japan  \
# Award
# 1 Star                     38.0          78.0           47.0          71.0
# 2 Stars                     6.0          17.0           12.0          10.0
# 3 Stars                     3.0           5.0            5.0           3.0
# Bib Gourmand               81.0          55.0           44.0          62.0
# Selected Restaurants      160.0         102.0          138.0          97.0
#
# Location              Seoul, South Korea  Bangkok, Thailand  Taipei, Taiwan  \
# Award
# 1 Star                              27.0               24.0            30.0
# 2 Stars                              9.0                7.0             4.0
# 3 Stars                              1.0                1.0             2.0
# Bib Gourmand                        58.0               40.0            43.0
# Selected Restaurants                91.0               97.0            80.0
#
# Location              ...  Isneauville, France  Isla Mujeres, Mexico  \
# Award                 ...
# 1 Star                ...                  NaN                   NaN
# 2 Stars               ...                  NaN                   NaN
# 3 Stars               ...                  NaN                   NaN
# Bib Gourmand          ...                  NaN                   NaN
# Selected Restaurants  ...                  1.0                   1.0
#
# Location              Inverness, USA  Iseo, Italy  Ischia, Italy  \
# Award
# 1 Star                           NaN          NaN            NaN
# 2 Stars                          NaN          NaN            1.0
# 3 Stars                          NaN          NaN            NaN
# Bib Gourmand                     NaN          NaN            NaN
# Selected Restaurants             1.0          1.0            NaN
#
# Location              Irouléguy, France  Irissarry, France  \
# Award
# 1 Star                              NaN                NaN
# 2 Stars                             NaN                NaN
# 3 Stars                             NaN                NaN
# Bib Gourmand                        NaN                1.0
# Selected Restaurants                1.0                NaN
#
# Location              Inworth, United Kingdom  Inverness, United Kingdom  \
# Award
# 1 Star                                    NaN                        NaN
# 2 Stars                                   NaN                        NaN
# 3 Stars                                   NaN                        NaN
# Bib Gourmand                              NaN                        NaN
# Selected Restaurants                      1.0                        1.0
#
# Location              Škofja Loka, Slovenia
# Award
# 1 Star                                  NaN
# 2 Stars                                 NaN
# 3 Stars                                 NaN
# Bib Gourmand                            NaN
# Selected Restaurants                    1.0
#
# [5 rows x 5801 columns]

# %%
#Plot city with the most Michelin Restaurants

df_top_city_count = df.groupby(['Award', 'Location']).size().reset_index(name = 'res_count')
df_top_city_count.sort_values(by = 'res_count', ascending= False, inplace = True)
df_top_city_count
# Out:
#                      Award                 Location  res_count
# 5994  Selected Restaurants            Paris, France        316
# 6986  Selected Restaurants             Tokyo, Japan        232
# 5354  Selected Restaurants   London, United Kingdom        209
# 6760  Selected Restaurants                Singapore        160
# 5791  Selected Restaurants            New York, USA        138
# ...                    ...                      ...        ...
# 2693          Bib Gourmand  Mora de Rubielos, Spain          1
# 2692          Bib Gourmand      Montrigiasco, Italy          1
# 2691          Bib Gourmand    Montreux, Switzerland          1
# 2690          Bib Gourmand      Montpellier, France          1
# 7445  Selected Restaurants    Škofja Loka, Slovenia          1
#
# [7446 rows x 3 columns]

# %%
#Awards

awards = ['Selected Restaurants', 'Bib Gourmand', '1 Star', '2 Stars', '3 Stars']

# %%
#Plot 
fig, ax = plt.subplots(len(awards),1)

for i, award in enumerate(awards):
    df_plot = df_top_city_count[df_top_city_count['Award'] == award].head(5)
    sns.barplot(data = df_plot, x = 'res_count', y = 'Location', ax = ax[i], hue = 'Location', palette = 'rocket')
    ax[i].set_title(award)
    ax[i].set_xlabel(' ')
    ax[i].set_xlim(0, 350)

fig.set_figheight(20)
fig.suptitle('Counts of Michelin Restaurants', fontsize = 15)

plt.show()

# %%
#Split country into its own column

# df_location = df['Location'].str.split(', ', n=1, expand = True).rename(columns = {0: 'City', 1: 'Country'})

# df_location.sample(10)

df[['City', 'Country']] = df['Location'].str.split(', ', n=1, expand = True)

# %% [markdown]
# Noted that in the ```Country``` column, there are less datapoints than that of ```City``` which means some ```Location``` do not have a country specificied.
#
# These are usually small countries or city states.
#
# The following codes are there to find out what are the names of the ```City```and replace the ```Country```with the same name instead of leaving it as ```null```.

# %%
#Find out what cities are these null countries
null_country = df[df['Country'].isnull()].index.tolist()
df.loc[null_country, 'City'].unique().tolist()
# Out:
# ['Singapore', 'Hong Kong', 'Macau', 'Dubai', 'Abu Dhabi', 'Luxembourg']

# %% [markdown]
# Now that we know all these "cities" are essentially city states or small countries, we can use ```fillna()``` to replace any ```null```values in the ```Country``` column.

# %%
#Fill null Country with City 
df['Country'] = df['Country'].fillna(df['City'])
df_HK = df[df['City'] == 'Hong Kong']
df_HK
# Out:
#                                Name  \
# 144                          Ta Vie
# 145                         Caprice
# 146    8 1/2 Otto e Mezzo - Bombana
# 148                           Forum
# 150                     T'ang Court
# ...                             ...
# 17194            Yuè (Causeway Bay)
# 17196                 The Merchants
# 17197         Tuber Umberto Bombana
# 17198             Hong Kong Cuisine
# 17199                      Mâm Amis
#
#                                                  Address  \
# 144    2F, The Pottinger Hotel, 21 Stanley Street, Ce...
# 145    6F, Four Seasons Hotel, 8 Finance Street, Cent...
# 146    Shop 202, 2F, Alexandra House, 18 Chater Road,...
# 148    1F, Sino Plaza, 255-257 Gloucester Road, Cause...
# 150    1-2F, The Langham Hotel, 8 Peking Road, Tsim S...
# ...                                                  ...
# 17194  Shop 1301, Food Forum, Time Square, 1 Matheson...
# 17196  43-45F, Forty-Five, Gloucester Tower, Landmark...
# 17197  Shop 113A, 1F, K11 Musea, 18 Salisbury Road, T...
# 17198  1F, Elegance Court, 2-4 Tsoi Tak Street, Happy...
# 17199  Shop A & B, GF, Fu Fai Commercial Centre, 27 H...
#
#                              Location Price               Cuisine   Longitude  \
# 144                         Hong Kong  $$$$            Innovative  114.155290
# 145                         Hong Kong  $$$$   French Contemporary  114.156610
# 146                         Hong Kong  $$$$               Italian  114.158670
# 148                         Hong Kong  $$$$             Cantonese  114.182191
# 150                         Hong Kong   $$$             Cantonese  114.169800
# ...                               ...   ...                   ...         ...
# 17194  Hong Kong, Hong Kong SAR China    $$             Cantonese  114.182082
# 17196  Hong Kong, Hong Kong SAR China   $$$          Shanghainese  114.157766
# 17197  Hong Kong, Hong Kong SAR China  $$$$               Italian  114.174595
# 17198  Hong Kong, Hong Kong SAR China   $$$  Chinese Contemporary  114.185713
# 17199  Hong Kong, Hong Kong SAR China    $$            Vietnamese  114.151184
#
#         Latitude   PhoneNumber  \
# 144    22.282766  8.522669e+10
# 145    22.286649  8.523197e+10
# 146    22.281464  8.522538e+10
# 148    22.281397  8.522870e+10
# 150    22.296572  8.522133e+10
# ...          ...           ...
# 17194  22.278351  8.522838e+10
# 17196  22.281566  8.522155e+10
# 17197  22.294305  8.522133e+10
# 17198  22.269546  8.522893e+10
# 17199  22.285118  8.522893e+10
#
#                                                      Url  \
# 144    https://guide.michelin.com/en/hong-kong-region...
# 145    https://guide.michelin.com/en/hong-kong-region...
# 146    https://guide.michelin.com/en/hong-kong-region...
# 148    https://guide.michelin.com/en/hong-kong-region...
# 150    https://guide.michelin.com/en/hong-kong-region...
# ...                                                  ...
# 17194  https://guide.michelin.com/en/hong-kong-region...
# 17196  https://guide.michelin.com/en/hong-kong-region...
# 17197  https://guide.michelin.com/en/hong-kong-region...
# 17198  https://guide.michelin.com/en/hong-kong-region...
# 17199  https://guide.michelin.com/en/hong-kong-region...
#
#                                               WebsiteUrl  \
# 144                             https://www.tavie.com.hk
# 145    https://www.fourseasons.com/hongkong/dining/re...
# 146                    https://www.ottoemezzobombana.com
# 148                   http://www.forumrestaurant1977.com
# 150    https://www.langhamhotels.com/en/the-langham/h...
# ...                                                  ...
# 17194   https://lubuds.com/yue-times-square-causeway-bay
# 17196                        https://themerchantshk.com/
# 17197                           http://www.octavo.com.hk
# 17198                           https://www.1983hkc.com/
# 17199                              https://mamamishk.com
#
#                       Award  GreenStar  \
# 144                 3 Stars          0
# 145                 3 Stars          0
# 146                 3 Stars          0
# 148                 3 Stars          0
# 150                 3 Stars          0
# ...                     ...        ...
# 17194  Selected Restaurants          0
# 17196  Selected Restaurants          0
# 17197  Selected Restaurants          0
# 17198  Selected Restaurants          0
# 17199  Selected Restaurants          0
#
#                                    FacilitiesAndServices  \
# 144                   Air conditioning,Wheelchair access
# 145    Air conditioning,Car park,Great view,Interesti...
# 146    Air conditioning,Car park,Interesting wine lis...
# 148    Air conditioning,Car park,Interesting wine lis...
# 150    Air conditioning,Car park,Restaurant offering ...
# ...                                                  ...
# 17194                          Air conditioning,Car park
# 17196               Air conditioning,Car park,Great view
# 17197    Air conditioning,Car park,Interesting wine list
# 17198  Air conditioning,Bring your own bottle,Restaur...
# 17199                                                NaN
#
#                                              Description       City  \
# 144    The mantra of chef Hideaki Sato is “pure, simp...  Hong Kong
# 145    One of Hong Kong's most glamorous and elegant ...  Hong Kong
# 146    Owner-chef Umberto Bombana’s restaurant, which...  Hong Kong
# 148    Co-founder and chef of this upmarket spot, the...  Hong Kong
# 150    Comfort and luxury partly explain the populari...  Hong Kong
# ...                                                  ...        ...
# 17194  Having worked in some prestigious kitchens in ...  Hong Kong
# 17196  The top three floors of a prestigious office t...  Hong Kong
# 17197  This dining concept by the eponymous chef is d...  Hong Kong
# 17198  This upstairs restaurant is helmed by Chef Li,...  Hong Kong
# 17199  The smart wood panelled front contrasts sharpl...  Hong Kong
#
#                    Country
# 144              Hong Kong
# 145              Hong Kong
# 146              Hong Kong
# 148              Hong Kong
# 150              Hong Kong
# ...                    ...
# 17194  Hong Kong SAR China
# 17196  Hong Kong SAR China
# 17197  Hong Kong SAR China
# 17198  Hong Kong SAR China
# 17199  Hong Kong SAR China
#
# [211 rows x 16 columns]

# %% [markdown]
# After a quick check, I found out that some of the ```Country``` for Hong Kong was named "Hong Kong SAR China" instead of just "Hong Kong". I need to clean this up and

# %%
#Changing "Hong Kong SAR China" in the ```Country``` column into "Hong Kong".
df.loc[df['Country'] == 'Hong Kong SAR China', 'Country'] = 'Hong Kong'

df_HK = df[df['City'] == 'Hong Kong']
df_HK
# Out:
#                                Name  \
# 144                          Ta Vie
# 145                         Caprice
# 146    8 1/2 Otto e Mezzo - Bombana
# 148                           Forum
# 150                     T'ang Court
# ...                             ...
# 17194            Yuè (Causeway Bay)
# 17196                 The Merchants
# 17197         Tuber Umberto Bombana
# 17198             Hong Kong Cuisine
# 17199                      Mâm Amis
#
#                                                  Address  \
# 144    2F, The Pottinger Hotel, 21 Stanley Street, Ce...
# 145    6F, Four Seasons Hotel, 8 Finance Street, Cent...
# 146    Shop 202, 2F, Alexandra House, 18 Chater Road,...
# 148    1F, Sino Plaza, 255-257 Gloucester Road, Cause...
# 150    1-2F, The Langham Hotel, 8 Peking Road, Tsim S...
# ...                                                  ...
# 17194  Shop 1301, Food Forum, Time Square, 1 Matheson...
# 17196  43-45F, Forty-Five, Gloucester Tower, Landmark...
# 17197  Shop 113A, 1F, K11 Musea, 18 Salisbury Road, T...
# 17198  1F, Elegance Court, 2-4 Tsoi Tak Street, Happy...
# 17199  Shop A & B, GF, Fu Fai Commercial Centre, 27 H...
#
#                              Location Price               Cuisine   Longitude  \
# 144                         Hong Kong  $$$$            Innovative  114.155290
# 145                         Hong Kong  $$$$   French Contemporary  114.156610
# 146                         Hong Kong  $$$$               Italian  114.158670
# 148                         Hong Kong  $$$$             Cantonese  114.182191
# 150                         Hong Kong   $$$             Cantonese  114.169800
# ...                               ...   ...                   ...         ...
# 17194  Hong Kong, Hong Kong SAR China    $$             Cantonese  114.182082
# 17196  Hong Kong, Hong Kong SAR China   $$$          Shanghainese  114.157766
# 17197  Hong Kong, Hong Kong SAR China  $$$$               Italian  114.174595
# 17198  Hong Kong, Hong Kong SAR China   $$$  Chinese Contemporary  114.185713
# 17199  Hong Kong, Hong Kong SAR China    $$            Vietnamese  114.151184
#
#         Latitude   PhoneNumber  \
# 144    22.282766  8.522669e+10
# 145    22.286649  8.523197e+10
# 146    22.281464  8.522538e+10
# 148    22.281397  8.522870e+10
# 150    22.296572  8.522133e+10
# ...          ...           ...
# 17194  22.278351  8.522838e+10
# 17196  22.281566  8.522155e+10
# 17197  22.294305  8.522133e+10
# 17198  22.269546  8.522893e+10
# 17199  22.285118  8.522893e+10
#
#                                                      Url  \
# 144    https://guide.michelin.com/en/hong-kong-region...
# 145    https://guide.michelin.com/en/hong-kong-region...
# 146    https://guide.michelin.com/en/hong-kong-region...
# 148    https://guide.michelin.com/en/hong-kong-region...
# 150    https://guide.michelin.com/en/hong-kong-region...
# ...                                                  ...
# 17194  https://guide.michelin.com/en/hong-kong-region...
# 17196  https://guide.michelin.com/en/hong-kong-region...
# 17197  https://guide.michelin.com/en/hong-kong-region...
# 17198  https://guide.michelin.com/en/hong-kong-region...
# 17199  https://guide.michelin.com/en/hong-kong-region...
#
#                                               WebsiteUrl  \
# 144                             https://www.tavie.com.hk
# 145    https://www.fourseasons.com/hongkong/dining/re...
# 146                    https://www.ottoemezzobombana.com
# 148                   http://www.forumrestaurant1977.com
# 150    https://www.langhamhotels.com/en/the-langham/h...
# ...                                                  ...
# 17194   https://lubuds.com/yue-times-square-causeway-bay
# 17196                        https://themerchantshk.com/
# 17197                           http://www.octavo.com.hk
# 17198                           https://www.1983hkc.com/
# 17199                              https://mamamishk.com
#
#                       Award  GreenStar  \
# 144                 3 Stars          0
# 145                 3 Stars          0
# 146                 3 Stars          0
# 148                 3 Stars          0
# 150                 3 Stars          0
# ...                     ...        ...
# 17194  Selected Restaurants          0
# 17196  Selected Restaurants          0
# 17197  Selected Restaurants          0
# 17198  Selected Restaurants          0
# 17199  Selected Restaurants          0
#
#                                    FacilitiesAndServices  \
# 144                   Air conditioning,Wheelchair access
# 145    Air conditioning,Car park,Great view,Interesti...
# 146    Air conditioning,Car park,Interesting wine lis...
# 148    Air conditioning,Car park,Interesting wine lis...
# 150    Air conditioning,Car park,Restaurant offering ...
# ...                                                  ...
# 17194                          Air conditioning,Car park
# 17196               Air conditioning,Car park,Great view
# 17197    Air conditioning,Car park,Interesting wine list
# 17198  Air conditioning,Bring your own bottle,Restaur...
# 17199                                                NaN
#
#                                              Description       City    Country
# 144    The mantra of chef Hideaki Sato is “pure, simp...  Hong Kong  Hong Kong
# 145    One of Hong Kong's most glamorous and elegant ...  Hong Kong  Hong Kong
# 146    Owner-chef Umberto Bombana’s restaurant, which...  Hong Kong  Hong Kong
# 148    Co-founder and chef of this upmarket spot, the...  Hong Kong  Hong Kong
# 150    Comfort and luxury partly explain the populari...  Hong Kong  Hong Kong
# ...                                                  ...        ...        ...
# 17194  Having worked in some prestigious kitchens in ...  Hong Kong  Hong Kong
# 17196  The top three floors of a prestigious office t...  Hong Kong  Hong Kong
# 17197  This dining concept by the eponymous chef is d...  Hong Kong  Hong Kong
# 17198  This upstairs restaurant is helmed by Chef Li,...  Hong Kong  Hong Kong
# 17199  The smart wood panelled front contrasts sharpl...  Hong Kong  Hong Kong
#
# [211 rows x 16 columns]

# %% [markdown]
# Checking other previously ```null``` countries have been cleared.

# %%
df_UAE = df[df['Country'] == 'United Arab Emirates']
df_UAE
# Out:
# Empty DataFrame
# Columns: [Name, Address, Location, Price, Cuisine, Longitude, Latitude, PhoneNumber, Url, WebsiteUrl, Award, GreenStar, FacilitiesAndServices, Description, City, Country]
# Index: []

# %%
#Plot country with the most amount of Michelin Restaurants

df_plot = df.groupby('Country').size().sort_values(ascending=False).head(10).reset_index(name = 'Count')

sns.barplot(data= df_plot, x = 'Country', y = 'Count', hue = 'Country', palette = 'rocket')
plt.xlabel('Country')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Countries with the most Michelin Restaurants in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %%
#Plot city with the most amount of Michelin Restaurants
df_plot = df.groupby('City').size().sort_values(ascending=False).head(10).reset_index(name = 'Count')

sns.barplot(data= df_plot, x = 'City', y = 'Count', hue = 'City', palette = 'rocket')
plt.xlabel('Country')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Cities with the most Michelin Restaurants in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# It's great that we found out France has the most Michelin Restaurants in the world in 2025. However, I am bougie and only wants to dine in restaurants that are awarded stars. I do not care about restaurants that are awarded as "Selected Restaurants" or " Bib Gourmand". Let's find out how many restaurants are in each categories for these top 10 countries.

# %%
df_country = df.pivot_table(index = 'Country', columns= 'Award', aggfunc='size', fill_value=0)

#Reorder the df accorindg to number of awards in each country
df_country.loc['Total'] = df_country.sum()

df_country = df_country[df_country.loc['Total'].sort_values(ascending=False).index]

#Drop Total row
df_country = df_country.drop('Total')

#Add a Total column in the pivot table to summarise the number of awards in each country
df_country["Total"] = df_country.sum(axis=1)

#Sort country according to the total number of awards in each country
df_country = df_country.sort_values(by = 'Total', ascending = False)

df_country.drop(columns = 'Total', inplace = True)

df_country
# Out:
# Award           Selected Restaurants  Bib Gourmand  1 Star  2 Stars  3 Stars
# Country
# France                          2014           374     512       74       30
# Italy                           1346           250     336       38       14
# USA                              892           382     214       32       14
# Germany                          752           195     266       47       10
# Spain                            750           213     241       32       16
# Japan                            475           245     299       56       20
# United Kingdom                   709           131     164       23       10
# Belgium                          495           124     111       21        2
# China Mainland                   244           183     109       18        4
# Switzerland                      292           113     104       25        4
# Netherlands                      295            82     101       19        1
# Thailand                         270           156      28        7        1
# Taiwan                           176           126      41        4        3
# Austria                          206            43      62       18        2
# Singapore                        160            81      38        6        3
# South Korea                      117            77      30        9        1
# Hong Kong                         76            59      58       12        6
# Portugal                         116            28      38        8        0
# Canada                           110            38      25        1        0
# Vietnam                           99            58       7        0        0
# Mexico                            97            42      16        2        0
# Malaysia                          80            56       6        1        0
# Brazil                            81            36      15        6        0
# Türkiye                           90            27      13        1        0
# Ireland                           63            18      16        5        0
# Dubai                             66            18      14        4        0
# Denmark                           49            18      21        7        3
# Croatia                           69            11      10        1        0
# Hungary                           57            11       8        2        0
# Poland                            54            16       5        1        0
# Sweden                            41            11      17        4        1
# Argentina                         54             7       6        1        0
# Slovenia                          43            10       8        1        1
# Macau                             28            10       8        5        2
# Luxembourg                        38             4       7        1        0
# Norway                            26             4      17        1        2
# Abu Dhabi                         37             7       4        0        0
# Malta                             30             5       6        1        0
# Greece                            17             6      11        1        0
# Estonia                           27             6       1        1        0
# Qatar                             27             4       2        0        0
# Lithuania                         24             4       4        0        0
# Latvia                            26             3       2        0        0
# Finland                           15             4       8        1        0
# Serbia                            19             2       2        0        0
# Czech Republic                    17             2       0        0        0
# Iceland                            5             0       3        0        0
# Andorra                            5             0       1        0        0
# Czechia                            1             2       2        0        0

# %% [markdown]
# Now that the table is sorted according, I am going to plot a stacked bar chart for the top 10 countries with the most Michelin restaurants in the world.
#
# *Note: plotting stacked bar chart was not part of the course that I took. So this is all self-taught by Google and ChatGPT.*

# %%
#Plot stacked bar chart for top 10 countries with the most Michelin restaurants in the world.

df_plot = df_country.head(10)
colours = sns.set_palette('rocket_r', n_colors=len(df_plot.columns))
df_plot.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('Country')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Countries with the most Michelin Restaurants in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(reverse = True)
plt.show()

# %% [markdown]
# I want to find out the best countries to go if I only want to go "starred" restaurants, i.e. excluding restaurants that are awared "Bib Gourmand" and "Selected Restaurants".

# %%
df_country_starred = df.pivot_table(index = 'Country', columns = 'Award', aggfunc = 'size', fill_value=0)
df_country_starred.drop(columns = ['Bib Gourmand', 'Selected Restaurants'], inplace = True)

#Reorder the df accorindg to number of awards in each country
df_country_starred.loc['Total'] = df_country_starred.sum()

df_country_starred = df_country_starred[df_country_starred.loc['Total'].sort_values(ascending=False).index]

#Drop Total row
df_country_starred = df_country_starred.drop('Total')

#Add a Total column in the pivot table to summarise the number of awards in each country
df_country_starred["Total"] = df_country_starred.sum(axis=1)

#Sort country according to the total number of awards in each country
df_country_starred = df_country_starred.sort_values(by = 'Total', ascending = False)

df_country_starred.drop(columns = 'Total', inplace = True)

df_country_starred
# Out:
# Award           1 Star  2 Stars  3 Stars
# Country
# France             512       74       30
# Italy              336       38       14
# Japan              299       56       20
# Germany            266       47       10
# Spain              241       32       16
# USA                214       32       14
# United Kingdom     164       23       10
# Belgium            111       21        2
# Switzerland        104       25        4
# China Mainland     109       18        4
# Netherlands        101       19        1
# Austria             62       18        2
# Hong Kong           58       12        6
# Taiwan              41        4        3
# Singapore           38        6        3
# Portugal            38        8        0
# South Korea         30        9        1
# Thailand            28        7        1
# Denmark             21        7        3
# Canada              25        1        0
# Sweden              17        4        1
# Ireland             16        5        0
# Brazil              15        6        0
# Norway              17        1        2
# Mexico              16        2        0
# Dubai               14        4        0
# Macau                8        5        2
# Türkiye             13        1        0
# Greece              11        1        0
# Croatia             10        1        0
# Hungary              8        2        0
# Slovenia             8        1        1
# Finland              8        1        0
# Luxembourg           7        1        0
# Malta                6        1        0
# Malaysia             6        1        0
# Argentina            6        1        0
# Vietnam              7        0        0
# Poland               5        1        0
# Abu Dhabi            4        0        0
# Lithuania            4        0        0
# Iceland              3        0        0
# Serbia               2        0        0
# Qatar                2        0        0
# Estonia              1        1        0
# Czechia              2        0        0
# Latvia               2        0        0
# Andorra              1        0        0
# Czech Republic       0        0        0

# %%
#Plot the top 10 countries with the most starred Michelin Restaurants. 
df_plot = df_country_starred.head(10)
colours = sns.set_palette('rocket_r', n_colors=len(df_plot.columns))
df_plot.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('Country')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Countries with the most Starred Michelin Restaurants in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(reverse = True)
plt.show()

# %%
#Plot top 10 citie with the most Starred michelin Restaurants in 2025
df_city_starred = df.pivot_table(index = 'City', columns = 'Award', aggfunc = 'size', fill_value=0)
df_city_starred.drop(columns = ['Bib Gourmand', 'Selected Restaurants'], inplace = True)

#Reorder the df accorindg to number of awards in each country
df_city_starred.loc['Total'] = df_city_starred.sum()

df_city_starred = df_city_starred[df_city_starred.loc['Total'].sort_values(ascending=False).index]

#Drop Total row
df_city_starred = df_city_starred.drop('Total')

#Add a Total column in the pivot table to summarise the number of awards in each country
df_city_starred["Total"] = df_city_starred.sum(axis=1)

#Sort country according to the total number of awards in each country
df_city_starred = df_city_starred.sort_values(by = 'Total', ascending = False)

df_city_starred.drop(columns = 'Total', inplace = True)

df_plot = df_city_starred.head(10)
colours = sns.set_palette('rocket_r', n_colors=len(df_plot.columns))
df_plot.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('City')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Cities with the most Starred Michelin Restaurants in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(reverse = True)
plt.show()

# %%
#what are the proportions of awards given to restaurants by the Michelin guide?

award_prop = df.groupby('Award').size().reset_index(name = 'award_count')
award_prop = award_prop.sort_values(by= 'award_count', ascending=False).set_index('Award')
awards = award_prop.index.tolist()
award_counts = award_prop['award_count'].tolist()

colours = sns.set_palette('rocket_r', n_colors=len(awards))
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(award_counts, labels=awards, colors=colours, startangle=144,autopct='%1.1f%%', labeldistance=1.2, pctdistance=1.1)

plt.ylabel('')
plt.title('Proportion of Awards given to Restaurants by Michelin Guide')
plt.show()

# %% [markdown]
# Find out which cuisine is most popular among Michelin guide.

# %%
cuisine = df.pivot_table(index = 'Cuisine', columns = 'Award', aggfunc = 'size', fill_value=0)
cuisine.sample(10)
# Out:
# Award                                    1 Star  2 Stars  3 Stars  \
# Cuisine
# Korean, Seasonal Cuisine                      1        0        0
# Udon, Japanese                                0        0        0
# Traditional Cuisine, Alsatian                 0        0        0
# Pork                                          0        0        0
# American, Mexican                             0        0        0
# Mediterranean Cuisine, Regional Cuisine       0        0        0
# Japanese, Contemporary                        5        1        0
# Sardinian, Traditional Cuisine                0        0        0
# Fusion, International                         1        0        0
# Hubei                                         0        0        0
#
# Award                                    Bib Gourmand  Selected Restaurants
# Cuisine
# Korean, Seasonal Cuisine                            0                     0
# Udon, Japanese                                      1                     0
# Traditional Cuisine, Alsatian                       1                     3
# Pork                                                1                     1
# American, Mexican                                   0                     1
# Mediterranean Cuisine, Regional Cuisine             1                     4
# Japanese, Contemporary                              0                     7
# Sardinian, Traditional Cuisine                      3                     1
# Fusion, International                               0                     1
# Hubei                                               2                     1

# %% [markdown]
# Found out that there are multiple entry for each cuisine. I need to explode this dataframe to get a more accurate understanding of the type of cuisines available.

# %%
df = pd.read_csv('michelin_my_maps.csv')
df['Cuisine'] = df['Cuisine'].str.split(',')
# df_cuisine_exploded = df.explode('Cuisine')
# df_cuisine_exploded
df
# Out:
#                                   Name  \
# 0                              Mingles
# 1                            L'Enclume
# 2      Alain Ducasse at The Dorchester
# 3      Hélène Darroze at The Connaught
# 4             Restaurant Gordon Ramsay
# ...                                ...
# 17741            La Finestra in Cucina
# 17742                       Kampa Park
# 17743                       La Veranda
# 17744                           Bockem
# 17745                            Aromi
#
#                                                  Address  \
# 0      2F, 19 Dosan-daero 67-gil, Gangnam-gu, Seoul, ...
# 1      Cavendish Street, Cartmel, LA11 6QA, United Ki...
# 2      Park Lane, Mayfair, London, W1K 1QA, United Ki...
# 3      Carlos Place, Mayfair, London, W1K 2AL, United...
# 4      68-69 Royal Hospital Road, Chelsea, London, SW...
# ...                                                  ...
# 17741      Platnérská 13, Prague, 110 00, Czech Republic
# 17742  Na Kampe 8b, Malá Strana, Prague, 118 00, Czechia
# 17743  Elišky Krásnohorské 2, Prague, 110 00, Czech R...
# 17744     Elišky Peškové 1095/5, Prague, 150 00, Czechia
# 17745            Námĕstí Míru 6, Prague, 120 00, Czechia
#
#                       Location Price                         Cuisine  \
# 0           Seoul, South Korea  ₩₩₩₩  [Korean,  Korean Contemporary]
# 1      Cartmel, United Kingdom  ££££              [Creative British]
# 2       London, United Kingdom  ££££                        [French]
# 3       London, United Kingdom  ££££                [Modern Cuisine]
# 4       London, United Kingdom  ££££                        [French]
# ...                        ...   ...                             ...
# 17741   Prague, Czech Republic     €                       [Italian]
# 17742   Prague, Czech Republic   €€€                [Modern Cuisine]
# 17743   Prague, Czech Republic    €€         [Mediterranean Cuisine]
# 17744   Prague, Czech Republic   €€€          [Czech,  Contemporary]
# 17745          Prague, Czechia   €€€                       [Italian]
#
#         Longitude   Latitude   PhoneNumber  \
# 0      127.044260  37.525350  8.225157e+09
# 1       -2.953868  54.201771  4.415395e+11
# 2       -0.152575  51.507338  4.420763e+11
# 3       -0.149290  51.510188  4.420315e+11
# 4       -0.162177  51.485438  4.420735e+11
# ...           ...        ...           ...
# 17741   14.416367  50.087338  4.202223e+11
# 17742   14.408992  50.087038  4.202968e+11
# 17743   14.419907  50.090262  4.202248e+11
# 17744   14.405282  50.077414  4.200770e+12
# 17745   14.436488  50.076217  4.202227e+11
#
#                                                      Url  \
# 0      https://guide.michelin.com/en/seoul-capital-ar...
# 1      https://guide.michelin.com/en/cumbria/cartmel/...
# 2      https://guide.michelin.com/en/greater-london/l...
# 3      https://guide.michelin.com/en/greater-london/l...
# 4      https://guide.michelin.com/en/greater-london/l...
# ...                                                  ...
# 17741  https://guide.michelin.com/en/prague/prague/re...
# 17742  https://guide.michelin.com/en/prague/prague/re...
# 17743  https://guide.michelin.com/en/prague/prague/re...
# 17744  https://guide.michelin.com/en/prague/prague/re...
# 17745  https://guide.michelin.com/en/prague/prague/re...
#
#                                               WebsiteUrl  \
# 0                    https://www.restaurant-mingles.com/
# 1                            https://www.lenclume.co.uk/
# 2               https://www.alainducasse-dorchester.com/
# 3      https://www.the-connaught.co.uk/restaurants-ba...
# 4      https://www.gordonramsayrestaurants.com/restau...
# ...                                                  ...
# 17741              https://lafinestra.lacollezione.cz/en
# 17742                          https://kampapark.com/en/
# 17743                           https://www.laveranda.cz
# 17744                                 https://bockem.cz/
# 17745                   https://aromi.lacollezione.cz/en
#
#                       Award  GreenStar  \
# 0                   3 Stars          0
# 1                   3 Stars          1
# 2                   3 Stars          0
# 3                   3 Stars          0
# 4                   3 Stars          0
# ...                     ...        ...
# 17741  Selected Restaurants          0
# 17742  Selected Restaurants          0
# 17743  Selected Restaurants          0
# 17744  Selected Restaurants          0
# 17745  Selected Restaurants          0
#
#                                    FacilitiesAndServices  \
# 0      Air conditioning,Interesting wine list,Valet p...
# 1      Air conditioning,Garden or park,Interesting wi...
# 2      Air conditioning,Interesting wine list,Restaur...
# 3      Air conditioning,Interesting wine list,Restaur...
# 4      Air conditioning,Interesting wine list,Restaur...
# ...                                                  ...
# 17741  Air conditioning,Booking essential - dinner,In...
# 17742  Air conditioning,Booking essential - dinner,Gr...
# 17743                                   Air conditioning
# 17744                                  Booking essential
# 17745     Air conditioning,Interesting wine list,Terrace
#
#                                              Description
# 0      Chef Kang Min-goo's keen eye for detail shines...
# 1      Exceptional produce is the bedrock of everythi...
# 2      Executive Chef Jean-Philippe Blondet is bringi...
# 3      A wood-panelled dining room within the histori...
# 4      He may be one of the most famous chefs on the ...
# ...                                                  ...
# 17741  Set in Prague's Old Town, this is a great esta...
# 17742  Kampa Park is stunningly located by the water’...
# 17743  In this restaurant with the flair of an Italia...
# 17744  There’s something very endearing about this wa...
# 17745  This attractive restaurant is accommodated in ...
#
# [17746 rows x 14 columns]

# %%
# df_cuisine = df_cuisine_exploded.groupby('Cuisine')['Award'].size()
# df_cuisine

# %%
# df = pd.read_csv('michelin_my_maps.csv')
# index = df[df['Cuisine'].str.contains('604-0941', na=False, regex=True)].index
# print(index)

# %%
# df.loc[index, 'Cuisine'] = 'Japanese'

# print(df.loc[index, 'Cuisine'])

# %%
# unique_cuisine = df_cuisine.index.to_list()
# unique_cuisine

# %%
df = pd.read_csv('michelin_my_maps.csv')

def replace_multiple_cuisines(cuisine):
    cuisines = cuisine.split(", ")  # Assuming cuisines are separated by commas
    if len(cuisines) > 1:
        return cuisines[0]  # Return the first cuisine
    return cuisine  # Return the original if only one cuisine

# Apply the function to the 'Cuisine' column
df_cuisine_grouped = df.copy()
df_cuisine_grouped['Cuisine'] = df_cuisine_grouped['Cuisine'].apply(replace_multiple_cuisines)

# Check the result
df_cuisine_grouped
# Out:
#                                   Name  \
# 0                              Mingles
# 1                            L'Enclume
# 2      Alain Ducasse at The Dorchester
# 3      Hélène Darroze at The Connaught
# 4             Restaurant Gordon Ramsay
# ...                                ...
# 17741            La Finestra in Cucina
# 17742                       Kampa Park
# 17743                       La Veranda
# 17744                           Bockem
# 17745                            Aromi
#
#                                                  Address  \
# 0      2F, 19 Dosan-daero 67-gil, Gangnam-gu, Seoul, ...
# 1      Cavendish Street, Cartmel, LA11 6QA, United Ki...
# 2      Park Lane, Mayfair, London, W1K 1QA, United Ki...
# 3      Carlos Place, Mayfair, London, W1K 2AL, United...
# 4      68-69 Royal Hospital Road, Chelsea, London, SW...
# ...                                                  ...
# 17741      Platnérská 13, Prague, 110 00, Czech Republic
# 17742  Na Kampe 8b, Malá Strana, Prague, 118 00, Czechia
# 17743  Elišky Krásnohorské 2, Prague, 110 00, Czech R...
# 17744     Elišky Peškové 1095/5, Prague, 150 00, Czechia
# 17745            Námĕstí Míru 6, Prague, 120 00, Czechia
#
#                       Location Price                Cuisine   Longitude  \
# 0           Seoul, South Korea  ₩₩₩₩                 Korean  127.044260
# 1      Cartmel, United Kingdom  ££££       Creative British   -2.953868
# 2       London, United Kingdom  ££££                 French   -0.152575
# 3       London, United Kingdom  ££££         Modern Cuisine   -0.149290
# 4       London, United Kingdom  ££££                 French   -0.162177
# ...                        ...   ...                    ...         ...
# 17741   Prague, Czech Republic     €                Italian   14.416367
# 17742   Prague, Czech Republic   €€€         Modern Cuisine   14.408992
# 17743   Prague, Czech Republic    €€  Mediterranean Cuisine   14.419907
# 17744   Prague, Czech Republic   €€€                  Czech   14.405282
# 17745          Prague, Czechia   €€€                Italian   14.436488
#
#         Latitude   PhoneNumber  \
# 0      37.525350  8.225157e+09
# 1      54.201771  4.415395e+11
# 2      51.507338  4.420763e+11
# 3      51.510188  4.420315e+11
# 4      51.485438  4.420735e+11
# ...          ...           ...
# 17741  50.087338  4.202223e+11
# 17742  50.087038  4.202968e+11
# 17743  50.090262  4.202248e+11
# 17744  50.077414  4.200770e+12
# 17745  50.076217  4.202227e+11
#
#                                                      Url  \
# 0      https://guide.michelin.com/en/seoul-capital-ar...
# 1      https://guide.michelin.com/en/cumbria/cartmel/...
# 2      https://guide.michelin.com/en/greater-london/l...
# 3      https://guide.michelin.com/en/greater-london/l...
# 4      https://guide.michelin.com/en/greater-london/l...
# ...                                                  ...
# 17741  https://guide.michelin.com/en/prague/prague/re...
# 17742  https://guide.michelin.com/en/prague/prague/re...
# 17743  https://guide.michelin.com/en/prague/prague/re...
# 17744  https://guide.michelin.com/en/prague/prague/re...
# 17745  https://guide.michelin.com/en/prague/prague/re...
#
#                                               WebsiteUrl  \
# 0                    https://www.restaurant-mingles.com/
# 1                            https://www.lenclume.co.uk/
# 2               https://www.alainducasse-dorchester.com/
# 3      https://www.the-connaught.co.uk/restaurants-ba...
# 4      https://www.gordonramsayrestaurants.com/restau...
# ...                                                  ...
# 17741              https://lafinestra.lacollezione.cz/en
# 17742                          https://kampapark.com/en/
# 17743                           https://www.laveranda.cz
# 17744                                 https://bockem.cz/
# 17745                   https://aromi.lacollezione.cz/en
#
#                       Award  GreenStar  \
# 0                   3 Stars          0
# 1                   3 Stars          1
# 2                   3 Stars          0
# 3                   3 Stars          0
# 4                   3 Stars          0
# ...                     ...        ...
# 17741  Selected Restaurants          0
# 17742  Selected Restaurants          0
# 17743  Selected Restaurants          0
# 17744  Selected Restaurants          0
# 17745  Selected Restaurants          0
#
#                                    FacilitiesAndServices  \
# 0      Air conditioning,Interesting wine list,Valet p...
# 1      Air conditioning,Garden or park,Interesting wi...
# 2      Air conditioning,Interesting wine list,Restaur...
# 3      Air conditioning,Interesting wine list,Restaur...
# 4      Air conditioning,Interesting wine list,Restaur...
# ...                                                  ...
# 17741  Air conditioning,Booking essential - dinner,In...
# 17742  Air conditioning,Booking essential - dinner,Gr...
# 17743                                   Air conditioning
# 17744                                  Booking essential
# 17745     Air conditioning,Interesting wine list,Terrace
#
#                                              Description
# 0      Chef Kang Min-goo's keen eye for detail shines...
# 1      Exceptional produce is the bedrock of everythi...
# 2      Executive Chef Jean-Philippe Blondet is bringi...
# 3      A wood-panelled dining room within the histori...
# 4      He may be one of the most famous chefs on the ...
# ...                                                  ...
# 17741  Set in Prague's Old Town, this is a great esta...
# 17742  Kampa Park is stunningly located by the water’...
# 17743  In this restaurant with the flair of an Italia...
# 17744  There’s something very endearing about this wa...
# 17745  This attractive restaurant is accommodated in ...
#
# [17746 rows x 14 columns]

# %%
df_cuisine_size = df_cuisine_grouped.groupby('Cuisine').size()
original_cuisines = df_cuisine_size.index.to_list()
original_cuisines
# Out:
# ['Afghan',
#  'African',
#  'Alpine',
#  'Alsatian',
#  'American',
#  'American Contemporary',
#  'Andalusian',
#  'Apulian',
#  'Argentinian',
#  'Armenian',
#  'Asian',
#  'Asian Contemporary',
#  'Asian Influences',
#  'Asian and Western',
#  'Asturian',
#  'Australian Contemporary',
#  'Austrian',
#  'Bakery',
#  'Balkan',
#  'Barbecue',
#  'Basque',
#  'Bavarian',
#  'Beef',
#  'Beijing Cuisine',
#  'Belgian',
#  'Bibimbap',
#  'Brazilian',
#  'Breton',
#  'British Contemporary',
#  'Bulgogi',
#  'Burgundian',
#  'Burmese',
#  'Calabrian',
#  'Californian',
#  'Cambodian',
#  'Campanian',
#  'Cantonese',
#  'Cantonese Roast Meats',
#  'Caribbean',
#  'Castilian',
#  'Catalan',
#  'Central Asian',
#  'Chao Zhou',
#  'Cheese',
#  'Chicken Specialities',
#  'Chinese',
#  'Chinese Contemporary',
#  'Chiu Chow',
#  'Chueotang',
#  'Classic Cuisine',
#  'Classic French',
#  'Colombian',
#  'Congee',
#  'Contemporary',
#  'Corsican',
#  'Country cooking',
#  'Crab Specialities',
#  'Creative',
#  'Creative British',
#  'Creative French',
#  'Creole',
#  'Croatian',
#  'Cuban',
#  'Cuisine from Abruzzo',
#  'Cuisine from Basilicata',
#  'Cuisine from Lazio',
#  'Cuisine from Romagna',
#  'Cuisine from South West France',
#  'Cuisine from Valtellina',
#  'Cuisine from the Aosta Valley',
#  'Cuisine from the Marches',
#  'Czech',
#  'Danish',
#  'Deli',
#  'Dim Sum',
#  'Doganitang',
#  'Dongbei',
#  'Dubu',
#  'Duck Specialities',
#  'Dumplings',
#  'Dwaeji-gukbap',
#  'Eastern European',
#  'Egyptian',
#  'Emilian',
#  'Emirati Cuisine',
#  'English',
#  'Ethiopian',
#  'European',
#  'European Contemporary',
#  'Farm to table',
#  'Filipino',
#  'Finnish',
#  'Flemish',
#  'French',
#  'French Contemporary',
#  'Friulian',
#  'Fugu / Pufferfish',
#  'Fujian',
#  'Fusion',
#  'Galician',
#  'Gastropub',
#  'Gejang',
#  'German',
#  'Gomtang',
#  'Greek',
#  'Grills',
#  'Hainanese',
#  'Hakkanese',
#  'Hang Zhou',
#  'Home Cooking',
#  'Hotpot',
#  'Huaiyang',
#  'Hubei',
#  'Hui Cuisine',
#  'Hunanese',
#  'Hungarian',
#  'Indian',
#  'Indian Vegetarian',
#  'Indonesian',
#  'Innovative',
#  'International',
#  'Irish',
#  'Isan',
#  'Israeli',
#  'Italian',
#  'Italian Contemporary',
#  'Italian and Japanese',
#  'Italian-American',
#  'Izakaya',
#  'Jamaican',
#  'Japanese',
#  'Japanese Contemporary',
#  'Japanese Steakhouse',
#  'Jiangzhe',
#  'Jokbal',
#  'Kalguksu',
#  'Korean',
#  'Korean Contemporary',
#  'Kushiage',
#  'Lamb Specialities',
#  'Lao',
#  'Latin American',
#  'Lebanese',
#  'Ligurian',
#  'Lombardian',
#  'Lyonnaise',
#  'Macanese',
#  'Malaysian',
#  'Mandu',
#  'Mantuan',
#  'Meats and Grills',
#  'Meats and Seafood',
#  'Mediterranean Cuisine',
#  'Memil-guksu',
#  'Mexican',
#  'Middle Eastern',
#  'Milanese',
#  'Modern British',
#  'Modern Cuisine',
#  'Modern French',
#  'Moroccan',
#  'Naengmyeon',
#  'Nepali',
#  'Ningbo',
#  'Noodles',
#  'Noodles and Congee',
#  'North African',
#  'Northern Thai',
#  'Norwegian',
#  'Obanzai',
#  'Oden',
#  'Onigiri',
#  'Organic',
#  'Pakistani',
#  'Peranakan',
#  'Persian',
#  'Peruvian',
#  'Piedmontese',
#  'Pizza',
#  'Polish',
#  'Pork',
#  'Portuguese',
#  'Provençal',
#  'Puerto Rican',
#  'Ramen',
#  'Regional Cuisine',
#  'Regional European',
#  'Rice Dishes',
#  'Roman',
#  'Russian',
#  'Sardinian',
#  'Savoyard',
#  'Scandinavian',
#  'Scottish',
#  'Seafood',
#  'Seasonal Cuisine',
#  'Seolleongtang',
#  'Shabu-shabu',
#  'Shandong',
#  'Shanghainese',
#  'Sharing',
#  'Shojin',
#  'Shun Tak',
#  'Sichuan',
#  'Sicilian',
#  'Singaporean',
#  'Singaporean and Malaysian',
#  'Small eats',
#  'Smørrebrød',
#  'Soba',
#  'South African',
#  'South American',
#  'South East Asian',
#  'South Indian',
#  'South Tyrolean',
#  'Southern',
#  'Southern Thai',
#  'Spanish',
#  'Spanish Contemporary',
#  'Sri Lankan',
#  'Steakhouse',
#  'Street Food',
#  'Sujebi',
#  'Sukiyaki',
#  'Sushi',
#  'Swabian',
#  'Swedish',
#  'Swiss',
#  'Taiwanese',
#  'Taiwanese contemporary',
#  'Taizhou',
#  'Tempura',
#  'Teochew',
#  'Teppanyaki',
#  'Tex-Mex',
#  'Thai',
#  'Thai contemporary',
#  'Thai-Chinese',
#  'Tibetan',
#  'Tonkatsu',
#  'Traditional British',
#  'Traditional Cuisine',
#  'Turkish',
#  'Tuscan',
#  'Udon',
#  'Umbrian',
#  'Unagi / Freshwater Eel',
#  'Vegan',
#  'Vegetarian',
#  'Venetian',
#  'Venezuelan',
#  'Vietnamese',
#  'Vietnamese Contemporary',
#  'World Cuisine',
#  'Xibei',
#  'Xinjiang',
#  'Yakitori',
#  'Yoshoku',
#  'Yukhoe',
#  'Yunnanese',
#  'Zhejiang']

# %% [markdown]
# It's clear that some of the cuisines here can be further summarised, e.g. Yakitori and Yoshoku can be grouped into Japanese. I copied ```df_cuisine_size``` into ChatGPT and asked it to summarise these 261 cuisines into 80 cuisines.

# %%
category_mapping = {
    'Afghan': ['Afghan'],
    'African': ['African', 'Ethiopian', 'North African'],
    'American': ['American', 'American Contemporary', 'Californian', 'Creole', 'Southern', 'Tex-Mex'],
    'Argentinian': ['Argentinian'],
    'Armenian': ['Armenian'],
    'Asian': ['Asian', 'Asian Contemporary', 'Asian Influences'],
    'Austalian': ['Australian Contemporary'],
    'Austrian': ['Austrian'],
    'BBQ': ['Barbecue', 'Grills', 'Meats and Grills', 'Meats and Seafood'],
    'Bakery': ['Bakery'],
    'Belgian': ['Belgian', 'Flemish'],
    'Brazilian': ['Brazilian'],
    'British': ['British Contemporary', 'Creative British', 'English', 'Gastropub', 'Modern British', 'Scottish', 'Traditional British'],
    'Burmese': ['Burmese'],
    'Cambodian': ['Cambodian'],
    'Carribean': ['Caribbean'],
    'Central Asian': ['Central Asian'],
    'Cheese': ['Cheese'],
    'Chinese': ['Beijing Cuisine', 'Cantonese', 'Cantonese Roast Meats', 'Chao Zhou', 'Chinese', 'Chinese Contemporary', 'Chiu Chow', 'Congee', 'Dim Sum', 'Dongbei', 'Fujian', 'Hainanese', 'Hakkanese', 'Hang Zhou', 'Huaiyang', 'Hubei', 'Hui Cuisine', 'Hunanese', 'Jiangzhe', 'Ningbo', 'Noodles and Congee', 'Shandong', 'Shanghainese', 'Shun Tak', 'Sichuan', 'Taiwanese', 'Taiwanese contemporary', 'Taizhou', 'Teochew', 'Tibetan', 'Xibei', 'Xinjiang', 'Yunnanese', 'Zhejian'],
    'Colombian': ['Colombian'],
    'Croatian': ['Croatian'],
    'Cuban': ['Cuban'],
    'Czech': ['Czech'],
    'Dumplings': ['Dumplings'],
    'Eastern European': ['Eastern European'],
    'Egyptian': ['Egyptian'],
    'European': ['Alpine', 'Alsatian', 'Balkan', 'Basque', 'Corsican', 'European', 'European Contemporary', 'Regional European', 'South Tyrolean'],
    'Filipino': ['Filipino'],
    'French': ['Breton', 'Burgundian', 'Classic French', 'Creative French', 'Cuisine from South West France', 'French', 'French Contemporary', 'Lyonnaise', 'Modern French', 'Provençal', 'Savoyard'],
    'Fusion': ['Asian and Western', 'Fusion', 'International', 'Italian and Japanese', 'Italian-American', 'Thai-Chinese', 'World Cuisine'],
    'German': ['Bavarian', 'German', 'Swabian'],
    'Greek': ['Greek'],
    'Hungarian': ['Hungarian'],
    'Indian': ['Indian', 'Indian Vegetarian', 'South Indian'],
    'Indonesian': ['Indonesian'],
    'Irish': ['Irish'],
    'Italian': ['Apulian', 'Calabrian', 'Campanian', 'Cuisine from Abruzzo', 'Cuisine from Basilicata', 'Cuisine from Lazio', 'Cuisine from Romagna', 'Cuisine from Valtellina', 'Cuisine from the Aosta Valley', 'Cuisine from the Marches', 'Emilian', 'Friulian', 'Italian', 'Italian Contemporary', 'Ligurian', 'Lombardian', 'Mantuan', 'Milanese', 'Piedmontese', 'Pizza', 'Roman', 'Sardinian', 'Sicilian', 'Tuscan', 'Umbrian', 'Venetian'],
    'Jamaican': ['Jamaican'],
    'Japanese': ['Fugu / Pufferfish', 'Izakaya', 'Japanese', 'Japanese Contemporary', 'Japanese Steakhouse', 'Kushiage', 'Obanzai', 'Oden', 'Onigiri', 'Ramen', 'Shabu-shabu', 'Shojin', 'Soba', 'Sukiyaki', 'Sushi', 'Tempura', 'Teppanyaki', 'Tonkatsu', 'Udon', 'Unagi / Freshwater Eel', 'Yakitori', 'Yoshoku'],
    'Korean': ['Bibimbap', 'Bulgogi', 'Chueotang', 'Doganitang', 'Dubu', 'Dwaeji-gukbap', 'Gejang', 'Gomtang', 'Jokbal', 'Kalguksu', 'Korean', 'Korean Contemporary', 'Mandu', 'Memil-guksu', 'Naengmyeon', 'Seolleongtang', 'Sujebi', 'Yukhoe'],
    'Lao': ['Lao'],
    'Latin American': ['Latin American'],
    'Lebanese': ['Lebanese'],
    'Macanese': ['Macanese'],
    'Meat': ['Beef', 'Chicken Specialities', 'Duck Specialities', 'Lamb Specialities', 'Pork', 'Steakhouse'],
    'Mediterranean': ['Mediterranean Cuisine'],
    'Mexican': ['Mexican'],
    'Middle Eastern': ['Emirati Cuisine', 'Israeli', 'Middle Eastern', 'Persian'],
    'Moroccan': ['Moroccan'],
    'Nepali': ['Nepali'],
    'Noodles': ['Noodles'],
    'Other': ['Classic Cuisine', 'Contemporary', 'Country cooking', 'Creative', 'Deli', 'Farm to table', 'Home Cooking', 'Hotpot', 'Innovative', 'Modern Cuisine', 'Organic', 'Regional Cuisine', 'Sharing', 'Small eats', 'Street Food', 'Traditional Cuisine'],
    'Pakistani': ['Pakistani'],
    'Peruvian': ['Peruvian'],
    'Polish': ['Polish'],
    'Portuguese': ['Portuguese'],
    'Puerto Rican': ['Puerto Rican'],
    'Rice': ['Rice Dishes'],
    'Russian': ['Russian'],
    'Scandinavian': ['Danish', 'Finnish', 'Norwegian', 'Scandinavian', 'Smørrebrød', 'Swedish'],
    'Seafood': ['Crab Specialities', 'Seafood', 'Seasonal Cuisine'],
    'South African': ['South African'],
    'South American': ['South American'],
    'South East Asian': ['Malaysian', 'Peranakan', 'Singaporean', 'Singaporean and Malaysian', 'South East Asian'],
    'Spanish': ['Andalusian', 'Asturian', 'Castilian', 'Catalan', 'Galician', 'Spanish', 'Spanish Contemporary'],
    'Sri Lankan': ['Sri Lankan'],
    'Swiss': ['Swiss'],
    'Thai': ['Isan', 'Northern Thai', 'Southern Thai', 'Thai', 'Thai contemporary'],
    'Turkish': ['Turkish'],
    'Vegan & Vegetarian': ['Vegan', 'Vegetarian'],
    'Venezuelan': ['Venezuelan'],
    'Vietnamese': ['Vietnamese', 'Vietnamese Contemporary']
}

# Create a reversed mapping from original cuisine to summarised cuisine
reverse_category_mapping = {orig: summarised for summarised, originals in category_mapping.items() for orig in originals}

# Function to categorize cuisines
def categorise_cuisine(cuisine):
    return reverse_category_mapping.get(cuisine, "Other")

df_cuisine_grouped['Summarised Cuisine'] = df_cuisine_grouped['Cuisine'].apply(categorise_cuisine)

df_cuisine_grouped[df_cuisine_grouped['Summarised Cuisine'] == 'Other'].sample(10)
# Out:
#                         Name  \
# 1441                  Ancòra
# 15991  Atelier Maître Albert
# 6614            Les Plaisirs
# 461                   akordu
# 8282            Humbachstube
# 7093                    Demo
# 1849                  Wöschi
# 10886               Il Pozzo
# 1314              Gente Rara
# 16593                Le Parc
#
#                                                  Address  \
# 1441           viale Trento 31, Cesenatico, 47042, Italy
# 15991          1 rue Maître-Albert, Paris, 75005, France
# 6614    2 rue Puada-dau-Gourguet, Peillon, 06440, France
# 461      70-1-3-1 Suimoncho, Nara, Nara, 630-8208, Japan
# 8282            Unterwestegg 17, Riezlern, 6991, Austria
# 7093   Plaza de Hernández Amores 4, Murcia, 30001, Spain
# 1849           Seestrasse 457, Zurich, 8038, Switzerland
# 10886       viale Allegri 7, Reggio Emilia, 42121, Italy
# 1314       Santiago Lapuente 10, Saragossa, 50014, Spain
# 16593        169 route d'Ottrott, Obernai, 67210, France
#
#                    Location Price              Cuisine   Longitude   Latitude  \
# 1441      Cesenatico, Italy   €€€       Modern Cuisine   12.404219  44.195566
# 15991         Paris, France    €€  Traditional Cuisine    2.350185  48.851148
# 6614        Peillon, France    €€     Regional Cuisine    7.381940  43.777982
# 461             Nara, Japan   ¥¥¥           Innovative  135.835467  34.685750
# 8282      Riezlern, Austria   €€€      Classic Cuisine   10.199680  47.366816
# 7093          Murcia, Spain    €€        Farm to table   -1.128415  37.984819
# 1849    Zurich, Switzerland   €€€       Modern Cuisine    8.538030  47.340512
# 10886  Reggio Emilia, Italy    €€  Traditional Cuisine   10.629300  44.701670
# 1314       Saragossa, Spain   €€€             Creative   -0.870545  41.658773
# 16593       Obernai, France   €€€       Modern Cuisine    7.471515  48.462460
#
#         PhoneNumber                                                Url  \
# 1441   3.905474e+11  https://guide.michelin.com/en/emilia-romagna/c...
# 15991  3.315681e+10  https://guide.michelin.com/en/ile-de-france/pa...
# 6614   3.349387e+10  https://guide.michelin.com/en/provence-alpes-c...
# 461    8.174277e+10  https://guide.michelin.com/en/nara-region/nara...
# 8282   4.355175e+09  https://guide.michelin.com/en/vorarlberg/riezl...
# 7093   3.460152e+10  https://guide.michelin.com/en/region-de-murcia...
# 1849   4.143243e+10  https://guide.michelin.com/en/zurich-region/zu...
# 10886  3.905225e+11  https://guide.michelin.com/en/emilia-romagna/i...
# 1314   3.462300e+10  https://guide.michelin.com/en/aragon/zaragoza/...
# 16593  3.338896e+10  https://guide.michelin.com/en/grand-est/oberna...
#
#                                     WebsiteUrl                 Award  \
# 1441            http://www.ancoracesenatico.it                1 Star
# 15991     https://www.ateliermaitrealbert.com/  Selected Restaurants
# 6614      https://www.lesplaisirs-peillon.com/          Bib Gourmand
# 461                        https://akordu.com/               2 Stars
# 8282   https://alpenhof-jaeger.at/restaurant#c  Selected Restaurants
# 7093              https://demopepemorales.com/  Selected Restaurants
# 1849                   https://www.woeschi.ch/                1 Star
# 10886                                      NaN  Selected Restaurants
# 1314                   http://www.genterara.es                1 Star
# 16593               https://www.leparchotel.fr  Selected Restaurants
#
#        GreenStar                             FacilitiesAndServices  \
# 1441           0           Air conditioning,Counter dining,Terrace
# 15991          0                    Air conditioning,Valet parking
# 6614           0                                               NaN
# 461            0   Air conditioning,Car park,Interesting wine list
# 8282           0        Car park,Garden or park,Great view,Terrace
# 7093           0                          Air conditioning,Terrace
# 1849           0                                  Car park,Terrace
# 10886          0                          Air conditioning,Terrace
# 1314           0                   Air conditioning,Counter dining
# 16593          0  Air conditioning,Car park,Garden or park,Terrace
#
#                                              Description Summarised Cuisine
# 1441   A new adventure for skilful chef Agostino Iaco...              Other
# 15991  An attractive medieval fireplace and roasting ...              Other
# 6614   This friendly family-run inn is tucked away in...              Other
# 461    ‘Akordu’ is Basque for ‘memories’. Chef Hirosh...              Other
# 8282   The Alpenhof Jäger hotel's restaurant may be s...              Other
# 7093   Located at the foot of the tower of the cathed...              Other
# 1849   Wöschi is located directly at Wollishofen harb...              Other
# 10886  This restaurant is housed in a historic palazz...              Other
# 1314   A restaurant with all the attributes required ...              Other
# 16593  On the outskirts of the town, this imposing Al...              Other

# %%
# index = df[df['Name'].str.contains('Tokumaru', na=False, regex=True)].index
# print(index)

# %%
# df.loc[index, 'Cuisine'] = 'Japanese'
# df.loc[index]
# df.to_csv('michelin_my_maps.csv', index= False)

# %%
# df = pd.read_csv('michelin_my_maps.csv')

# %%
df_1 = df_cuisine_grouped.groupby('Cuisine').size().sort_values(ascending=False).head(10).reset_index(name = 'Count')

df_1
# Out:
#                  Cuisine  Count
# 0         Modern Cuisine   3377
# 1               Creative   1039
# 2    Traditional Cuisine    934
# 3           Contemporary    923
# 4               Japanese    757
# 5                Italian    614
# 6                Seafood    593
# 7                 French    496
# 8  Mediterranean Cuisine    414
# 9          Farm to table    411

# %%
sns.barplot(data= df_1, x = 'Cuisine', y = 'Count', hue = 'Cuisine', palette = 'rocket')
plt.xlabel('Cuisine')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Cuisines Awared with Michelin regconition in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# What about which cuisine is most likely to get a star?

# %%
# df_cuisine_grouped 
# df_cuisine_grouped

df_cuisine_starred = df_cuisine_grouped.pivot_table(index = 'Cuisine', columns = 'Award', aggfunc = 'size', fill_value= 0)
df_cuisine_starred = df_cuisine_starred.drop(columns = ['Bib Gourmand', 'Selected Restaurants'])

df_cuisine_starred['Total'] = df_cuisine_starred.sum(axis = 1)

df_cuisine_starred = df_cuisine_starred.sort_values(by = 'Total', ascending= False)
df_cuisine_starred = df_cuisine_starred.drop(columns = 'Total')


df_plot = df_cuisine_starred.head(10)
df_plot
colours = sns.set_palette('rocket_r', n_colors=len(df_plot.columns))
df_plot.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('Cuisine')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Cuisine award with Michelin Stars in 2025')
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(reverse = True)
plt.show()

# %% [markdown]
# Using ```Summarised Cuisine``` instead.

# %%
df_2 = df_cuisine_grouped.groupby('Summarised Cuisine').size().sort_values(ascending=False).head(10).reset_index(name = 'Count')

df_2
# Out:
#   Summarised Cuisine  Count
# 0              Other   8322
# 1            Italian   1345
# 2           Japanese   1248
# 3             French   1173
# 4            Chinese    837
# 5            Seafood    743
# 6             Fusion    424
# 7      Mediterranean    414
# 8            British    399
# 9               Thai    321

# %%
sns.barplot(data= df_2, x = 'Summarised Cuisine', y = 'Count', hue = 'Summarised Cuisine', palette = 'rocket')
plt.xlabel('Cuisine')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Cuisines Awared with Michelin regconition in 2025')
import matplotlib as mpl
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %%
df_cuisine_starred = df_cuisine_grouped.pivot_table(index = 'Summarised Cuisine', columns = 'Award', aggfunc = 'size', fill_value= 0)
df_cuisine_starred = df_cuisine_starred.drop(columns = ['Bib Gourmand', 'Selected Restaurants'])

df_cuisine_starred['Total'] = df_cuisine_starred.sum(axis = 1)

df_cuisine_starred = df_cuisine_starred.sort_values(by = 'Total', ascending= False)
df_cuisine_starred = df_cuisine_starred.drop(columns = 'Total')


df_plot = df_cuisine_starred.head(10)
df_plot
colours = sns.set_palette('rocket_r', n_colors=len(df_plot.columns))
df_plot.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('Cuisine')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Top 10 Cuisine award with Michelin Stars in 2025')
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(reverse = True)
plt.show()

# %%
df.pivot_table(index = 'Price', columns = 'Award', aggfunc = 'size', fill_value=0)
# Out:
# Award  1 Star  2 Stars  3 Stars  Bib Gourmand  Selected Restaurants
# Price
# $           2        0        0           272                   224
# $$         43        1        0           560                   538
# $$$       109       11        2            29                   680
# $$$$      291       62       26             1                   415
# £           0        0        0             2                    11
# ££          0        0        0           127                   288
# £££        48        0        0             2                   317
# ££££      116       23       10             0                    93
# ¥           0        0        0           187                    28
# ¥¥         20        1        0           240                   178
# ¥¥¥       260       25        2             1                   462
# ¥¥¥¥      128       48       22             0                    50
# ฿           0        0        0            79                    57
# ฿฿          1        0        0            77                   116
# ฿฿฿        13        0        0             0                    71
# ฿฿฿฿       14        7        1             0                    26
# ₩           0        0        0            71                    21
# ₩₩          3        0        0             6                    51
# ₩₩₩        11        0        0             0                    26
# ₩₩₩₩       16        9        1             0                    19
# ₫           0        0        0            48                    27
# ₫₫          2        0        0            10                    37
# ₫₫₫         0        0        0             0                    25
# ₫₫₫₫        5        0        0             0                    10
# €           0        0        0           243                   244
# €€         23        0        0          1291                  3439
# €€€       703        2        0            25                  2726
# €€€€     1194      307       86             0                   483
# ₺           0        0        0            12                     4
# ₺₺          2        0        0            15                    31
# ₺₺₺         4        0        0             0                    42
# ₺₺₺₺        7        1        0             0                    13
# ﷼           0        0        0             1                     2
# ﷼﷼          0        0        0             3                     4
# ﷼﷼﷼         1        0        0             0                    13
# ﷼﷼﷼﷼        1        0        0             0                     8

# %%
# df['Price_level'] = df['Price'].str.len()
# index = df[df['Price_level'].isnull()].index
# print(index)
# df.loc[index, 'Price'] = '¥¥'
# df.loc[index]

df['Price_level'] = df['Price'].str.len().astype(int)
df.drop(columns = ' Price')
df_price_level = df.copy()
df_price_level.drop(columns = ' Price')
df.drop(columns = ' Price')
df.to_csv('michelin_my_maps.csv', index= False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17746 entries, 0 to 17745
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   17746 non-null  object
#  1   Address                17746 non-null  object
#  2   Location               17746 non-null  object
#  3   Price                  17746 non-null  object
#  4   Cuisine                17746 non-null  object
#  5   Longitude              17746 non-null  float64
#  6   Latitude               17746 non-null  float64
#  7   PhoneNumber            17377 non-null  float64
#  8   Url                    17746 non-null  object
#  9   WebsiteUrl             15242 non-null  object
#  10  Award                  17746 non-null  object
#  11  GreenStar              17746 non-null  int64
#  12  FacilitiesAndServices  16827 non-null  object
#  13  Description            17746 non-null  object
#  14  Price_level            17746 non-null  int32
#  15   Price                 1 non-null      object
# dtypes: float64(3), int32(1), int64(1), object(11)
# memory usage: 2.1+ MB

# %%
# df.drop(columns = ' Price', inplace = True)
df.to_csv('michelin_my_maps.csv', index= False)

# %%
df = pd.read_csv('michelin_my_maps.csv')
df
# Out:
#                                   Name  \
# 0                              Mingles
# 1                            L'Enclume
# 2      Alain Ducasse at The Dorchester
# 3      Hélène Darroze at The Connaught
# 4             Restaurant Gordon Ramsay
# ...                                ...
# 17741            La Finestra in Cucina
# 17742                       Kampa Park
# 17743                       La Veranda
# 17744                           Bockem
# 17745                            Aromi
#
#                                                  Address  \
# 0      2F, 19 Dosan-daero 67-gil, Gangnam-gu, Seoul, ...
# 1      Cavendish Street, Cartmel, LA11 6QA, United Ki...
# 2      Park Lane, Mayfair, London, W1K 1QA, United Ki...
# 3      Carlos Place, Mayfair, London, W1K 2AL, United...
# 4      68-69 Royal Hospital Road, Chelsea, London, SW...
# ...                                                  ...
# 17741      Platnérská 13, Prague, 110 00, Czech Republic
# 17742  Na Kampe 8b, Malá Strana, Prague, 118 00, Czechia
# 17743  Elišky Krásnohorské 2, Prague, 110 00, Czech R...
# 17744     Elišky Peškové 1095/5, Prague, 150 00, Czechia
# 17745            Námĕstí Míru 6, Prague, 120 00, Czechia
#
#                       Location Price                      Cuisine   Longitude  \
# 0           Seoul, South Korea  ₩₩₩₩  Korean, Korean Contemporary  127.044260
# 1      Cartmel, United Kingdom  ££££             Creative British   -2.953868
# 2       London, United Kingdom  ££££                       French   -0.152575
# 3       London, United Kingdom  ££££               Modern Cuisine   -0.149290
# 4       London, United Kingdom  ££££                       French   -0.162177
# ...                        ...   ...                          ...         ...
# 17741   Prague, Czech Republic     €                      Italian   14.416367
# 17742   Prague, Czech Republic   €€€               Modern Cuisine   14.408992
# 17743   Prague, Czech Republic    €€        Mediterranean Cuisine   14.419907
# 17744   Prague, Czech Republic   €€€          Czech, Contemporary   14.405282
# 17745          Prague, Czechia   €€€                      Italian   14.436488
#
#         Latitude   PhoneNumber  \
# 0      37.525350  8.225157e+09
# 1      54.201771  4.415395e+11
# 2      51.507338  4.420763e+11
# 3      51.510188  4.420315e+11
# 4      51.485438  4.420735e+11
# ...          ...           ...
# 17741  50.087338  4.202223e+11
# 17742  50.087038  4.202968e+11
# 17743  50.090262  4.202248e+11
# 17744  50.077414  4.200770e+12
# 17745  50.076217  4.202227e+11
#
#                                                      Url  \
# 0      https://guide.michelin.com/en/seoul-capital-ar...
# 1      https://guide.michelin.com/en/cumbria/cartmel/...
# 2      https://guide.michelin.com/en/greater-london/l...
# 3      https://guide.michelin.com/en/greater-london/l...
# 4      https://guide.michelin.com/en/greater-london/l...
# ...                                                  ...
# 17741  https://guide.michelin.com/en/prague/prague/re...
# 17742  https://guide.michelin.com/en/prague/prague/re...
# 17743  https://guide.michelin.com/en/prague/prague/re...
# 17744  https://guide.michelin.com/en/prague/prague/re...
# 17745  https://guide.michelin.com/en/prague/prague/re...
#
#                                               WebsiteUrl  \
# 0                    https://www.restaurant-mingles.com/
# 1                            https://www.lenclume.co.uk/
# 2               https://www.alainducasse-dorchester.com/
# 3      https://www.the-connaught.co.uk/restaurants-ba...
# 4      https://www.gordonramsayrestaurants.com/restau...
# ...                                                  ...
# 17741              https://lafinestra.lacollezione.cz/en
# 17742                          https://kampapark.com/en/
# 17743                           https://www.laveranda.cz
# 17744                                 https://bockem.cz/
# 17745                   https://aromi.lacollezione.cz/en
#
#                       Award  GreenStar  \
# 0                   3 Stars          0
# 1                   3 Stars          1
# 2                   3 Stars          0
# 3                   3 Stars          0
# 4                   3 Stars          0
# ...                     ...        ...
# 17741  Selected Restaurants          0
# 17742  Selected Restaurants          0
# 17743  Selected Restaurants          0
# 17744  Selected Restaurants          0
# 17745  Selected Restaurants          0
#
#                                    FacilitiesAndServices  \
# 0      Air conditioning,Interesting wine list,Valet p...
# 1      Air conditioning,Garden or park,Interesting wi...
# 2      Air conditioning,Interesting wine list,Restaur...
# 3      Air conditioning,Interesting wine list,Restaur...
# 4      Air conditioning,Interesting wine list,Restaur...
# ...                                                  ...
# 17741  Air conditioning,Booking essential - dinner,In...
# 17742  Air conditioning,Booking essential - dinner,Gr...
# 17743                                   Air conditioning
# 17744                                  Booking essential
# 17745     Air conditioning,Interesting wine list,Terrace
#
#                                              Description  Price_level
# 0      Chef Kang Min-goo's keen eye for detail shines...            4
# 1      Exceptional produce is the bedrock of everythi...            4
# 2      Executive Chef Jean-Philippe Blondet is bringi...            4
# 3      A wood-panelled dining room within the histori...            4
# 4      He may be one of the most famous chefs on the ...            4
# ...                                                  ...          ...
# 17741  Set in Prague's Old Town, this is a great esta...            1
# 17742  Kampa Park is stunningly located by the water’...            3
# 17743  In this restaurant with the flair of an Italia...            2
# 17744  There’s something very endearing about this wa...            3
# 17745  This attractive restaurant is accommodated in ...            3
#
# [17746 rows x 15 columns]

# %%
df_1Star_Bib = df[df['Award'].isin(['Bib Gourmand', '1 Star'])].copy()
df_plot = df_1Star_Bib.pivot_table(index = 'Award', columns = 'Price_level', aggfunc='size')
df_plot
# Out:
# Price_level     1     2     3     4
# Award
# 1 Star          2    94  1149  1772
# Bib Gourmand  915  2329    57     1

# %%
#Plot
colours = sns.set_palette('rocket_r', n_colors=len(df_plot.columns))
df_plot.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('Award level')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Number of 1 Star and Bib Gourmand Restaurants by Pirce Level')
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(reverse = True)
plt.show()

# %%
df_plot_2 = df.pivot_table(index = 'Award', columns = 'Price_level', aggfunc='size', fill_value=0)
df_plot_2['Total'] = df_plot_2.sum(axis=1)
df_plot_2 = df_plot_2.sort_values(by= 'Total', ascending=False)
df_plot_2 = df_plot_2.drop(columns = 'Total')

# %%
#Plot
colours = sns.set_palette('rocket_r', n_colors=len(df_plot_2.columns))
df_plot_2.plot(kind = 'bar', stacked = True, color= colours)

plt.xlabel('Award level')
plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Count of Restaurant')
plt.title('Number of Restaurants by Award Level and Pirce Level')
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(['1 Cheapest', '2', '3', '4 Most Expensive'],reverse = True, title = 'Price Level')
plt.show()

# %%
print(len(category_mapping))
# Out:
# 72
